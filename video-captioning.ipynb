# %%
import numpy as np
import cv2
import os
import torch
import spacy
import pandas as pd
import torchvision.transforms as T

from torchvision.io.video import read_video
from tqdm.notebook import tqdm
from PIL import Image
from torch.utils.data import DataLoader,Dataset
from collections import Counter
from IPython.display import clear_output

# %%
# !python -m spacy download ru_core_news_lg
# Out:
# 2023-10-01 02:54:58.721795: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting ru-core-news-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.6.0/ru_core_news_lg-3.6.0-py3-none-any.whl (513.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-lg==3.6.0) (3.6.1)
# Collecting pymorphy3>=1.0.0 (from ru-core-news-lg==3.6.0)
#   Downloading pymorphy3-1.2.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 2.1 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy3>=1.0.0->ru-core-news-lg==3.6.0)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt-ng>=0.6 (from pymorphy3>=1.0.0->ru-core-news-lg==3.6.0)
#   Downloading docopt_ng-0.9.0-py3-none-any.whl (16 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-lg==3.6.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 33.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (0.1.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->ru-core-news-lg==3.6.0) (2.1.3)
# Installing collected packages: pymorphy3-dicts-ru, dawg-python, docopt-ng, pymorphy3, ru-core-news-lg
# Successfully installed dawg-python-0.7.2 docopt-ng-0.9.0 pymorphy3-1.2.1 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp ./drive/MyDrive/rutube_hackathon_novosibirsk.zip ./rutube_hackathon_novosibirsk.zip

# %%
# !zip -FF ./rutube_hackathon_novosibirsk.zip --out ./pleasework.zip
clear_output()

# %%
# !unzip -qq ./pleasework.zip

# %%
spacy_ru = spacy.load("ru_core_news_lg")

text = "Сергей Чуприн любит hi! ОН - КАРТОфЕЛЕЛЮБ!!!"
[token.text.lower() for token in spacy_ru.tokenizer(text)]
# Out:
# ['сергей',
#  'чуприн',
#  'любит',
#  'hi',
#  '!',
#  'он',
#  '-',
#  'картофелелюб',
#  '!',
#  '!',
#  '!']

# %%
train_csv = pd.read_csv("./rutube_hackathon_novosibirsk/train/train.csv")

# %%
train_csv["len"] = train_csv["description"].apply(lambda x: len(x.split()))

# %%
train_csv.len.max()
# Out:
# 321

# %%
train_csv
# Out:
#     video_name stt_name category_name  \
# 0        0.mp4    0.txt   Развлечения
# 1        1.mp4    1.txt    Спорт/Игры
# 2        2.mp4    2.txt         Блоги
# 3        3.mp4    3.txt   Путешествия
# 4        4.mp4    4.txt     Искусство
# ..         ...      ...           ...
# 495    495.mp4  495.txt          Юмор
# 496    496.mp4  496.txt     Лайфстайл
# 497    497.mp4  497.txt   Развлечения
# 498    498.mp4  498.txt   Развлечения
# 499    499.mp4  499.txt         Блоги
#
#                                                  title  \
# 0                                 Правильная цена I #3
# 1                       Три лошадиные силы | Выпуск №2
# 2    Хашлама | Выпуск 4 | Силиконовый ПРЕСС Давы | ...
# 3                     Прогулка по стране - Владивосток
# 4        Артмеханика. Выпуск 3. Татуировки + Mika Vino
# ..                                                 ...
# 495  Тот самый мент I Выпуск 3I Мента забирают в армию
# 496  Сколько Стоит День? Выпуск 7. Сколько тратит в...
# 497                               Правильная цена I #4
# 498                                  Тру ДЕТЕКТОР I #6
# 499                        Какова Меркурия? | Выпуск 3
#
#                                            description  len
# 0    С вами Макс Климток и это шоу Правильная цена!...   53
# 1    В этом новом выпуске нас ждут не менее новые и...   46
# 2    Привет, это Султан и Авет! Мы опять хаваем вку...   58
# 3    Прогулка по Владивостоку. Самому большому горо...   42
# 4    Были ли татуировки на теле Николая II? Почему ...   62
# ..                                                 ...  ...
# 495  В начале рабочего дня Максиму Константиновичу ...   56
# 496  Сегодня мы провели целый день с певицей, актри...   68
# 497  С вами Макс Климток и это шоу Правильная цена!...   54
# 498  Вы смотрите шоу с детектором лжи «Тру ДЕТЕКТОР...   93
# 499  Действительно ли овны самые конфликтные? А бли...   42
#
# [500 rows x 6 columns]

# %%
class Vocabulary:
    def __init__(self,freq_threshold):
        self.itos = {0:"<PAD>", 1:"<SOS>", 2:"<EOS>", 3:"<UNK>"}

        self.stoi = {v:k for k,v in self.itos.items()}

        self.freq_threshold = freq_threshold

    def __len__(self): return len(self.itos)

    @staticmethod
    def tokenize(text):
        return [token.text.lower() for token in spacy_ru.tokenizer(text)]

    @staticmethod
    def del_timestamps(texts):
        output = ""
        for text in texts.split("\n"):
          output += "".join(text.split("]  ")[1:]) + " "
        return " ".join(text)

    def build_vocab(self, sentence_list, texts_list):
      frequencies = Counter()
      idx = 4

      for sentence in tqdm(sentence_list):
          for word in self.tokenize(sentence):
              frequencies[word] += 1

              if frequencies[word] == self.freq_threshold:
                  self.stoi[word] = idx
                  self.itos[idx] = word
                  idx += 1

      for text in tqdm(texts_list):
          text = self.del_timestamps(text)
          for word in self.tokenize(text):
              frequencies[word] += 1

              if frequencies[word] == self.freq_threshold:
                  self.stoi[word] = idx
                  self.itos[idx] = word
                  idx += 1

    def numericalize(self,text):
        tokenized_text = self.tokenize(text)
        return [ self.stoi[token] if token in self.stoi else self.stoi["<UNK>"] for token in tokenized_text ]

# %%
class VideoDataset(Dataset):
    def __init__(self, root_dir, captions, video_files, texts, transform=None,freq_threshold=1, build=True):
        self.root_dir = root_dir
        self.transform = transform

        self.imgs = video_files
        self.captions = captions

        text = []
        for file in tqdm(text):
            with open(self.root_dir + "/test_stt/" + file) as cf:
                    text.append(" ".join(cf.readlines()))

        self.vocab = Vocabulary(freq_threshold)
        if build:
            self.vocab.build_vocab(self.captions, texts)


    def __len__(self):
        return len(self.imgs)

    def _read_video(self, path, frames_num=25, window=30):
        frames = []
        cap = cv2.VideoCapture(self.root_dir + "/test_video/" + path)

        fps = int(cap.get(cv2.CAP_PROP_FPS))

        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        N = length // (frames_num)

        current_frame = 1
        for i in range(length):
            ret, frame = cap.read(current_frame)
            if ret and i == current_frame and len(frames) < frames_num:
                size = 226, 226
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame = cv2.resize(frame, size)
                frames.append(frame)
                current_frame += N


        cap.release()

        return np.array(frames)

    def __getitem__(self,idx):
        caption = self.captions[idx]
        img = self.imgs[idx]

        img = np.rollaxis(self._read_video(self.imgs[idx]), 3, 0)
        img = np.array(np.array(img) / 255, dtype=np.float32)


        caption_vec = []
        caption_vec += [self.vocab.stoi["<SOS>"]]
        caption_vec += self.vocab.numericalize(caption)
        caption_vec += [self.vocab.stoi["<EOS>"]]
        if len(caption_vec) < 300:
            for i in range(300 - len(caption_vec)):
                caption_vec.append(0)

        return torch.tensor(img), torch.tensor(caption_vec[:300])

# %%
data_location =  "./rutube_hackathon_novosibirsk/train"
BATCH_SIZE = 10

transforms = T.Compose([
    T.Resize(226),
    T.RandomCrop(224),
    T.ToTensor(),
    T.Normalize((0.485, 0.456, 0.406),(0.229, 0.224, 0.225))
])


dataset =  VideoDataset(
    root_dir=data_location,
    captions=train_csv.description.tolist(),
    texts=train_csv.stt_name.tolist(),
    video_files=train_csv.video_name,
    transform=transforms
)

data_loader = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    # batch_first=False
)

vocab_size = len(dataset.vocab)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-65e154713e8a> in <cell line: 12>()
#      12 dataset =  VideoDataset(
#      13     root_dir=data_location,
# ---> 14     captions=train_csv.description.tolist(),
#      15     texts=train_csv.stt_name.tolist(),
#      16     video_files=train_csv.video_name,
#
# NameError: name 'train_csv' is not defined

# %% [markdown]
# ### 3) Defining the Model Architecture
#
# Model is seq2seq model. In the **encoder** pretrained ResNet model is used to extract the features. Decoder, is the implementation of the Bahdanau Attention Decoder. In the decoder model **LSTM cell**.

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.models as models
import torchvision.models.video as video

from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as T

# %%
class VideoEncoderCNN(nn.Module):
    def __init__(self):
        super(VideoEncoderCNN, self).__init__()
        self.swin_t = video.swin3d_s(pretrained=True)
        for param in self.swin_t.parameters():
            param.requires_grad_(False)

        modules = list(self.swin_t.children())[:-2]
        self.swin_t = nn.Sequential(*modules)


    def forward(self, images):
        features = self.swin_t(images)
        features = features.view(features.size(0), -1, features.size(-1))

        return features

# %%
class VideoAttention(nn.Module):
    def __init__(self, encoder_dim,decoder_dim,attention_dim):
        super(VideoAttention, self).__init__()

        self.attention_dim = attention_dim

        self.W = nn.Linear(decoder_dim,attention_dim)
        self.U = nn.Linear(encoder_dim,attention_dim)

        self.A = nn.Linear(attention_dim,1)




    def forward(self, features, hidden_state):
        u_hs = self.U(features)
        w_ah = self.W(hidden_state)

        combined_states = torch.tanh(u_hs + w_ah.unsqueeze(1))

        attention_scores = self.A(combined_states)
        attention_scores = attention_scores.squeeze(2)


        alpha = F.softmax(attention_scores,dim=1)

        attention_weights = features * alpha.unsqueeze(2)
        attention_weights = attention_weights.sum(dim=1)

        return alpha,attention_weights

# %%
class VideoDecoderRNN(nn.Module):
    def __init__(self,embed_size, vocab_size, attention_dim,encoder_dim,decoder_dim,drop_prob=0.3):
        super().__init__()

        self.vocab_size = vocab_size
        self.attention_dim = attention_dim
        self.decoder_dim = decoder_dim

        self.embedding = nn.Embedding(vocab_size,embed_size)
        self.attention = VideoAttention(encoder_dim,decoder_dim,attention_dim)


        self.init_h = nn.Linear(encoder_dim, decoder_dim)
        self.init_c = nn.Linear(encoder_dim, decoder_dim)
        self.lstm_cell = nn.LSTMCell(embed_size+encoder_dim,decoder_dim,bias=True)
        self.f_beta = nn.Linear(decoder_dim, encoder_dim)


        self.fcn = nn.Linear(decoder_dim,vocab_size)
        self.drop = nn.Dropout(drop_prob)



    def forward(self, features, captions):
        embeds = self.embedding(captions)

        h, c = self.init_hidden_state(features)

        seq_length = len(captions[0])-1
        batch_size = captions.size(0)
        num_features = features.size(1)

        preds = torch.zeros(batch_size, seq_length, self.vocab_size).to(device)
        alphas = torch.zeros(batch_size, seq_length,num_features).to(device)

        for s in range(seq_length):
            alpha,context = self.attention(features, h)
            lstm_input = torch.cat((embeds[:, s], context), dim=1)
            h, c = self.lstm_cell(lstm_input, (h, c))

            output = self.fcn(self.drop(h))

            preds[:,s] = output
            alphas[:,s] = alpha


        return preds, alphas

    def generate_caption(self,features, max_len=300 ,vocab=None):

        batch_size = features.size(0)
        h, c = self.init_hidden_state(features)

        alphas = []
        word = torch.tensor(vocab.stoi['<SOS>']).view(1,-1).to(device)
        embeds = self.embedding(word)


        captions = []

        for i in range(max_len):
            alpha,context = self.attention(features, h)

            alphas.append(alpha.cpu().detach().numpy())

            lstm_input = torch.cat((embeds[:, 0], context), dim=1)
            h, c = self.lstm_cell(lstm_input, (h, c))
            output = self.fcn(self.drop(h))
            output = output.view(batch_size,-1)


            predicted_word_idx = output.argmax(dim=1)

            captions.append(predicted_word_idx.item())

            if vocab.itos[predicted_word_idx.item()] == "<EOS>":
                break

            embeds = self.embedding(predicted_word_idx.unsqueeze(0))

        return [vocab.itos[idx] for idx in captions],alphas


    def init_hidden_state(self, encoder_out):
        mean_encoder_out = encoder_out.mean(dim=1)
        h = self.init_h(mean_encoder_out)
        c = self.init_c(mean_encoder_out)
        return h, c

# %%
class VideoEncoderDecoder(nn.Module):
    def __init__(self,embed_size, vocab_size, attention_dim,encoder_dim,decoder_dim,drop_prob=0.3):
        super().__init__()
        self.encoder = VideoEncoderCNN()
        self.decoder = VideoDecoderRNN(
            embed_size=embed_size,
            vocab_size = vocab_size,
            attention_dim=attention_dim,
            encoder_dim=encoder_dim,
            decoder_dim=decoder_dim
        )

    def forward(self, images, captions):
        features = self.encoder(images)
        outputs = self.decoder(features, captions)
        return outputs

# %% [markdown]
# ### 4) Setting Hypperparameter and Init the model

# %%
#Hyperparams
embed_size=300
vocab_size = len(dataset.vocab)
attention_dim=256
encoder_dim=768
decoder_dim=512
learning_rate = 3e-4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fee7ef076f9a> in <cell line: 3>()
#       1 #Hyperparams
#       2 embed_size=300
# ----> 3 vocab_size = len(dataset.vocab)
#       4 attention_dim=256
#       5 encoder_dim=768
#
# NameError: name 'dataset' is not defined

# %%
#init model
model = VideoEncoderDecoder(
    embed_size=embed_size,
    vocab_size=vocab_size,
    attention_dim=attention_dim,
    encoder_dim=encoder_dim,
    decoder_dim=decoder_dim
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=dataset.vocab.stoi["<PAD>"])
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Swin3D_S_Weights.KINETICS400_V1`. You can also use `weights=Swin3D_S_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# !pip install av

# %%
#helper function to save the model
def save_model(model,num_epochs):
    model_state = {
        'num_epochs':num_epochs,
        'embed_size':embed_size,
        'vocab_size':len(dataset.vocab),
        'attention_dim':attention_dim,
        'encoder_dim':encoder_dim,
        'decoder_dim':decoder_dim,
        'state_dict':model.state_dict()
    }

    torch.save(model_state,'./drive/MyDrive/attention_model_state.pth')

# %% [markdown]
# ## 5) Training Job from above configs

# %%
torch.cuda.empty_cache()

# %%
import nltk
from nltk.translate import meteor
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def score(text, text_sum):
    text = text.replace("<PAD>", "")
    if isinstance(text_sum, str):
        return round(meteor([word_tokenize(text)],word_tokenize(text_sum)), 4)
    else:
        return 0

# %%
num_epochs = 25
print_every = 10

for epoch in tqdm(range(1, num_epochs + 1)):
    losses = []
    print(f"Epoch: {epoch}")
    try:
        for idx, (image, captions) in tqdm(enumerate(data_loader), total=len(data_loader)):
            # print(image.shape[2])
            # if image.shape[2] < 50:
            #     continue
            image, captions = image.to(device),captions.to(device)

            optimizer.zero_grad()

            outputs,attentions = model(image, captions)

            loss = criterion(outputs.view(-1, vocab_size), captions[:, 1:].reshape(-1))

            loss.backward()

            optimizer.step()
            losses.append(loss.item())

            if idx % print_every == 0:
                model.eval()
                with torch.no_grad():
                    dataiter = iter(data_loader)
                    img,targ = next(dataiter)
                    features = model.encoder(img[0:1].to(device))
                    caps, alphas = model.decoder.generate_caption(features, vocab=dataset.vocab)
                    caption = ' '.join(caps)
                    target = " ".join([dataset.vocab.itos[i] for i in targ[0:1][0][1:].tolist()])
                    print("true:", target)
                    print("pred:", caption)
                    print("loss:", loss.item(), "score:", score(target, caption))


                model.train()
    except Exception as ex:
        print("Err:", ex)
        raise ex
    if len(losses) != 0:
        print("Epoch loss: {:.5f}".format(sum(losses) / len(losses)))
    else:
        print(losses)
    #save the latest model
    save_model(model,epoch)
    # clear_output(wait=True)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch: 1
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 8.915692329406738 score: 0.0263
# loss: 8.47883129119873 score: 0.0227
# loss: 7.248097896575928 score: 0.0176
# loss: 7.123484134674072 score: 0.0221
# loss: 7.134592533111572 score: 0.0329
# Epoch loss: 7.71725
# Epoch: 2
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 6.8723602294921875 score: 0.0586
# loss: 6.755800724029541 score: 0.0215
# loss: 7.180953502655029 score: 0.0404
# loss: 6.811089515686035 score: 0.0333
# loss: 6.925175666809082 score: 0.0339
# Epoch loss: 6.94436
# Epoch: 3
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 6.799895286560059 score: 0.0
# loss: 6.690213680267334 score: 0.035
# loss: 6.404407978057861 score: 0.0714
# loss: 6.941572189331055 score: 0.0514
# loss: 6.587986469268799 score: 0.0461
# Epoch loss: 6.66533
# Epoch: 4
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 6.638942718505859 score: 0.0668
# loss: 6.679940223693848 score: 0.0705
# loss: 6.0935235023498535 score: 0.0299
# loss: 5.891200065612793 score: 0.1907
# loss: 5.950171947479248 score: 0.0146
# Epoch loss: 6.36518
# Epoch: 5
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 6.25126314163208 score: 0.0626
# loss: 5.922518253326416 score: 0.1466
# loss: 5.785062313079834 score: 0.0868
# loss: 6.2370781898498535 score: 0.0484
# loss: 5.428935527801514 score: 0.0916
# Epoch loss: 6.06080
# Epoch: 6
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 5.95467472076416 score: 0.1083
# loss: 5.955918312072754 score: 0.0415
# loss: 5.710024356842041 score: 0.1817
# loss: 5.569047927856445 score: 0.0738
# loss: 5.560596942901611 score: 0.2745
# Epoch loss: 5.78921
# Epoch: 7
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 5.892467975616455 score: 0.0702
# loss: 5.5397467613220215 score: 0.2647
# loss: 5.37299108505249 score: 0.1006
# loss: 5.445064544677734 score: 0.3061
# loss: 5.559462547302246 score: 0.095
# Epoch loss: 5.50988
# Epoch: 8
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 5.931407451629639 score: 0.092
# loss: 5.735106468200684 score: 0.0357
# loss: 4.981560230255127 score: 0.2068
# loss: 5.473208427429199 score: 0.1597
# loss: 4.724553108215332 score: 0.0064
# Epoch loss: 5.25738
# Epoch: 9
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 5.153927326202393 score: 0.0727
# loss: 5.4027791023254395 score: 0.0525
# loss: 4.786442756652832 score: 0.1953
# loss: 5.465935230255127 score: 0.1197
# loss: 4.611083030700684 score: 0.0737
# Epoch loss: 5.00303
# Epoch: 10
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 4.671930313110352 score: 0.0754
# loss: 4.525778770446777 score: 0.1134
# loss: 4.630340576171875 score: 0.1006
# loss: 4.911326885223389 score: 0.1403
# loss: 4.17954158782959 score: 0.0734
# Epoch loss: 4.77379
# Epoch: 11
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 4.671368598937988 score: 0.0915
# loss: 4.824629783630371 score: 0.2686
# loss: 4.054232597351074 score: 0.1709
# loss: 4.467138767242432 score: 0.1411
# loss: 4.65294075012207 score: 0.1559
# Epoch loss: 4.55529
# Epoch: 12
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 4.7070698738098145 score: 0.2637
# loss: 4.263211727142334 score: 0.1122
# loss: 4.448678016662598 score: 0.1097
# loss: 3.7467827796936035 score: 0.1396
# loss: 4.59494161605835 score: 0.5906
# Epoch loss: 4.31986
# Epoch: 13
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 3.1243600845336914 score: 0.096
# loss: 4.167882919311523 score: 0.0849
# loss: 4.1580810546875 score: 0.3283
# loss: 3.797739267349243 score: 0.3159
# loss: 4.178073406219482 score: 0.405
# Epoch loss: 4.13995
# Epoch: 14
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 4.586398124694824 score: 0.2958
# loss: 3.7238595485687256 score: 0.3034
# loss: 3.8958935737609863 score: 0.1517
# loss: 4.710023403167725 score: 0.3202
# loss: 3.929929256439209 score: 0.0984
# Epoch loss: 3.90703
# Epoch: 15
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 3.4666404724121094 score: 0.2181
# loss: 3.590632200241089 score: 0.2459
# loss: 3.414557695388794 score: 0.1622
# loss: 4.01615571975708 score: 0.1363
# loss: 4.424407005310059 score: 0.0455
# Epoch loss: 3.72151
# Epoch: 16
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 3.253783941268921 score: 0.0712
# loss: 3.0496017932891846 score: 0.5472
# loss: 3.980968952178955 score: 0.1852
# loss: 3.9288644790649414 score: 0.0455
# loss: 3.392162561416626 score: 0.23
# Epoch loss: 3.57036
# Epoch: 17
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 3.2838175296783447 score: 0.1983
# loss: 3.1512959003448486 score: 0.0996
# loss: 3.2098710536956787 score: 0.324
# loss: 3.754456043243408 score: 0.091
# loss: 3.884165048599243 score: 0.2066
# Epoch loss: 3.36377
# Epoch: 18
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.4741642475128174 score: 0.1738
# loss: 3.038079023361206 score: 0.3497
# loss: 3.3952219486236572 score: 0.2654
# loss: 3.9681546688079834 score: 0.1641
# loss: 3.0849618911743164 score: 0.339
# Epoch loss: 3.20564
# Epoch: 19
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 3.7605862617492676 score: 0.1783
# loss: 3.1154775619506836 score: 0.2251
# loss: 3.4027419090270996 score: 0.3025
# loss: 2.947638750076294 score: 0.2038
# loss: 3.5853614807128906 score: 0.0543
# Epoch loss: 3.05595
# Epoch: 20
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.4285850524902344 score: 0.161
# loss: 2.9569919109344482 score: 0.7833
# loss: 3.0592637062072754 score: 0.1127
# loss: 3.1344974040985107 score: 0.2867
# loss: 3.3452725410461426 score: 0.0704
# Epoch loss: 2.91555
# Epoch: 21
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.4120092391967773 score: 0.0693
# loss: 2.3151001930236816 score: 0.0994
# loss: 2.563652515411377 score: 0.0879
# loss: 2.2399256229400635 score: 0.1346
# loss: 2.7522597312927246 score: 0.1972
# Epoch loss: 2.76233
# Epoch: 22
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.526745080947876 score: 0.6283
# loss: 1.8728582859039307 score: 0.1602
# loss: 2.629197597503662 score: 0.2587
# loss: 2.0636894702911377 score: 0.1508
# loss: 2.0626513957977295 score: 0.0414
# Epoch loss: 2.62310
# Epoch: 23
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.7467591762542725 score: 0.467
# loss: 2.439303159713745 score: 0.086
# loss: 1.9384729862213135 score: 0.3129
# loss: 2.513373374938965 score: 0.0873
# loss: 2.6745805740356445 score: 0.2657
# Epoch loss: 2.47120
# Epoch: 24
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 2.4338889122009277 score: 0.2219
# loss: 1.7518889904022217 score: 0.3628
# loss: 2.1144773960113525 score: 0.7563
# loss: 2.2498204708099365 score: 0.7166
# loss: 2.5680336952209473 score: 0.2869
# Epoch loss: 2.35807
# Epoch: 25
#   0%|          | 0/50 [00:00<?, ?it/s]
# loss: 1.9401556253433228 score: 0.1478
# loss: 2.2931458950042725 score: 0.6116
# loss: 2.0408644676208496 score: 0.1866
# loss: 2.161356210708618 score: 0.1696
# loss: 1.8561944961547852 score: 0.5481
# Epoch loss: 2.21570

# %%
checkpoint = torch.load("./drive/MyDrive/video_model.pth")

# %%
model = VideoEncoderDecoder(
    embed_size=checkpoint["embed_size"],
    vocab_size =checkpoint["vocab_size"],
    attention_dim=checkpoint["attention_dim"],
    encoder_dim=checkpoint["encoder_dim"],
    decoder_dim=checkpoint["decoder_dim"]
).to(device)
model.load_state_dict(checkpoint["state_dict"])
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Swin3D_S_Weights.KINETICS400_V1`. You can also use `weights=Swin3D_S_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <All keys matched successfully>

# %%
# !wget https://lodmedia.hb.bizmrg.com/case_files/1026506/test_dataset_test.zip
# Out:
# --2023-10-01 02:59:53--  https://lodmedia.hb.bizmrg.com/case_files/1026506/test_dataset_test.zip
# Resolving lodmedia.hb.bizmrg.com (lodmedia.hb.bizmrg.com)... 95.163.53.117
# Connecting to lodmedia.hb.bizmrg.com (lodmedia.hb.bizmrg.com)|95.163.53.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1696238228 (1.6G) [application/zip]
# Saving to: ‘test_dataset_test.zip’
#
# test_dataset_test.z 100%[===================>]   1.58G  48.0MB/s    in 50s
#
# 2023-10-01 03:00:44 (32.5 MB/s) - ‘test_dataset_test.zip’ saved [1696238228/1696238228]

# %%
import pickle

# %%
# !unzip -qq test_dataset_test.zip

# %%
train_csv = pd.read_csv("./test/test.csv")

# %%
sample_submission = pd.read_csv("./sample_submission.csv")

# %%
sample_submission.head()
# Out:
#   video_name generated_description
# 0      0.mp4   Полученное описание
# 1      1.mp4   Полученное описание
# 2      2.mp4   Полученное описание
# 3      3.mp4   Полученное описание
# 4      4.mp4   Полученное описание

# %%
data_location =  "./test/"
BATCH_SIZE = 1

transforms = T.Compose([
    T.Resize(226),
    T.RandomCrop(224),
    T.ToTensor(),
    T.Normalize((0.485, 0.456, 0.406),(0.229, 0.224, 0.225))
])


dataset =  VideoDataset(
    root_dir=data_location,
    captions=train_csv.video_name.tolist(),
    texts=train_csv.stt_name.tolist(),
    video_files=train_csv.video_name,
    transform=transforms,
    build=False
)

dataset.vocab = pickle.load(open("./vocab.pkl", "rb"))


data_loader = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    # batch_first=False
)

vocab_size = len(dataset.vocab)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# 0it [00:00, ?it/s]
# device(type='cuda', index=0)

# %%
import string

# %%
scores = []
model.eval()

for idx, (image, captions) in tqdm(enumerate(data_loader), total=len(data_loader)):
    img, targ = image.to(device),captions.to(device)
    with torch.no_grad():
        features = model.encoder(img[0:1].to(device))
        caps, alphas = model.decoder.generate_caption(features, vocab=dataset.vocab)
        caption = ' '.join(caps)
        caption = caption.replace("<EOS>", "")
        for i in string.punctuation:
            if i not in ["/", "\\", "-"]:
                caption = caption.replace(f" {i}", i)
        # print(targ, caption)
        sample_submission.loc[sample_submission.video_name == f"{idx}.mp4", "generated_description"] = [caption]
        print(caption)
        # target = " ".join([dataset.vocab.itos[i] for i in targ[0:1][0][1:].tolist()])

        # scores.append(score(target, caption))
        # print("true:", target)
        # print("pred:", caption)
        # print("loss:", loss.item(), "score:", score(target, caption))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# добро пожаловать на канал « бюро добрых дел »! его глава – это я, лариса брохман. а миссия нашего бюро – искать самые добрые и хорошие новости по всему миру, чтобы рассказать их вам. в этом выпуске:   - /   - /   - /   - /   - /   ссылка на email   в этом выпуске:   - /   - /   - /   в этом выпуске - /   гость - специальный гость шоу « пацанский клининг », чтобы рассказать их вам. в этом выпуске: -   гость - ксения егорова в рамках рубрики « добрый репортаж », чтобы поднять вам настроение сделать ваш день чуточку радостнее и светлее.   пишите свои добрые истории нам на почту: email   по вопросам рекламы пишите на email
# знаете, как в котором комики играют и не менее от шефа.
# вы смотрите шоу с детектором лжи « тру детектор »! шоу, в котором кристи крайм и её молчаливый друг приглашают в гости известных людей и задают им неудобные вопросы под пристальным взором полиграфа. в этом выпуске, что скрывают звёзды и их ближайшее окружение? какие вопросы они зададут друг другу? и кто окажется самым лживым в компании? все это узнаёте в шоу тру детектор!
# в этом выпуске: антон протеинов - /   - /   в этом выпуске - / максим народный - /   в котором кристи - сазонов совместно со звездными гостями любыми способами пытаются найти номер и дозвониться известным артистам шоу, а также по вопросам рекламы пишите на email
# в этом выпуске ведущая алиса и дизайнер наталья, как с бюджетом в 25, чтобы из них. но и как всегда, чтобы не только на что они. что такое, что они готовы ради? и кто окажется самым лживым в компании.   а если уже посмотрели, то, что такое, что такое. а кто же не только на необычную.   что такое, как правильно нужно? как правильно? как правильно? как правильно? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? как всегда? смотри в новом выпуске шоу « пацанский клининг ».
# сегодня семён, сундук, и тяпа, егор и это не только, а также не только на канал и оставить. сегодня мы узнаем, как в ценах ориентируются, а также не только на передаче, а также не только на сайте. по вопросам рекламы пишите на email
# в этом выпуске шоу « стендап » с женей искандаровой.
# в этом выпуске вы узнаете, как правильно нужно, как правильно нужно, как правильно нужно, а также и как правильно.
# добро пожаловать на шоу « о чем молчат мужчины ». здесь парни говорят о том, о чем им не принято говорить. в этом выпуске вместе с оскаром.
# motorcity собрала на льду фестиваль скорости « байкальская миля ».
# почти половина" представляет в шоу" путь бойца". в этом выпуске реалити - шоу" путь бойца". в этом выпуске, а также не только им, но и пять, конечно же, кто из них сильнее!
# в этом выпуске вы узнаете, как правильно нужно, как правильно нужно, чтобы в гости к своему.
# сегодня султан - это шоу, в котором комики играют в мафию и пьют горячительные. сегодня мы узнаем, как правильно, как правильно сделать, которые написаны в сегодняшнем выпуске.
# добро пожаловать на аукцион шоу в котором подписчики делают ставки за вещи своего любимого блогера! сделать ставку может каждый сидящий в зале, в качестве ставки принимается всё кроме денег, ну а ставки помогает сделать ведущий шоу игорь чехов.   в этом выпуске, фанаты не только боролись за личные вещи кумира, на что они готовы ради вещей? тогда скорее смотрите выпуск.   а если уже посмотрели, то поделитесь выпуском с друзьями кто знает, может быть именно ваш кумир окажется на аукционе в следующем выпуске.
# в этом выпуске профессиональный - зоя, как предприниматель кирилл в мафию и пьют. сегодня мы будем, как в ценах ориентируются, а также и конечно же, кто из них сильнее!
# назаров по вопросам рекламы на email
# на связующих - это шоу, в котором кирилл фокин - сазонов совместно со звездными гостями любыми способами пытаются найти номер и дозвониться известным артистам шоу - бизнеса. сегодня в гостях – это шоу, а звонить мы будем будем!
# на связующих - это шоу, в котором кирилл фокин - сазонов совместно со звездными гостями любыми способами пытаются найти номер и дозвониться известным артистам шоу - бизнеса. сегодня в гостях – это шоу, а звонить мы будем будем!
# в этом выпуске ведущая алиса и дизайнер наталья, как правильно с бюджетом и суммировали все чеки.   в этом выпуске аня хилькевич расскажет, как правильно и дизайнер наталья, чтобы поднять вам. в этом выпуске вы узнаете, как правильно нужно, как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно? как правильно
# вы смотрите шоу с детектором лжи тру детектор! шоу в котором кристи крайм и её молчаливый друг приглашают в гости известных людей и задают им неудобные вопросы под пристальным взором полиграфа. в этом выпуске, в логово кристи и мистера молчуна попал попал и мистера молчуна попал, что их ближайшее окружение? какие вопросы они зададут друг другу? и кто окажется самым лживым в компании? все это узнаёте в шоу тру детектор!
# это алкомафия! шоу, в котором комики играют в мафию и пьют горячительные напитки. градус игры повышается с каждым выпитым бокалом. на розливе ведущий семен голубь. сегодня мы узнаем, как зовут, а звонить мы будем, а звонить мы будем!
# в этом выпуске “ мама 21 века ” расскажет марина дворникова.
# в этом выпуске « стендап » - как расскажет, как правильно и как правильно? как это в новом выпуске « мама-21 ».
# с вами макс климток и это шоу правильная цена! шоу, в котором участники зарабатывают баллы, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, подписаться и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, подписаться и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, подписаться и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, угадывая правильные цены товаров и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов
# недовольна, как вести себя в 25 тысяч рублей? и как сделать сделать, как правильно, что и что делать в новом выпуске.
# в этом выпуске - зоя, как правильно и дизайнер новости в новом выпуске tiktok дайджеста.
# на связующих в этом выпуске аня хилькевич расскажет, как правильно и сделать, как правильно сделать, что такое, что такое и его в новом выпуске аня хилькевич расскажет, как правильно сделать, что такое, что такое и его в новом выпуске аня хилькевич расскажет, как правильно сделать, а также сделать ваш на что и что делать в новом выпуске аня хилькевич.
# в этом выпуске ведущая алиса и дизайнер наталья, как правильно, как правильно нужно, как правильно нужно, что такое, что такое и как правильно сделать, как сделать ваш день чуточку радостнее и светлее.
# как молодому фотографу в новом выпуске шоу « стендап ».
# в этой серии максим константинович константинович, а канал подпиской!
# отправились с парнями на рыбалку. половили на рыбалку. что он натворил на природе. смотрите в этом выпуске.
# добро пожаловать на канал « бюро добрых дел »! его глава – это я, лариса брохман. а миссия нашего бюро – искать самые добрые и хорошие новости по всему миру, чтобы рассказать их вам. в этом выпуске:   - /   ссылка на email
# в этом выпуске « 3 » », как правильно и его из самых.
# в этом выпуске ведущая алиса и дизайнер наташа с бюджетом в 25 тысяч рублей. и кто из них за деньги и бесплатно.
# действительно ли овны самые конфликтные? а близнецы двуличные? сегодня это выяснят комики, что эффективнее: прислушиваться прислушиваться к звёздам или ориентироваться на юмор и интуицию? узнаем в сегодняшнем выпуске шоу « какова меркурия » с женей искандаровой.
# макс и лиза максу и лиза, что они не чистить, чтобы они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они узнали, чтобы они и макса в прошлое, чтобы они и макса в прошлое, чтобы они и макса в прошлое, чтобы они и макса в прошлое, чтобы они и макса в прошлое, чтобы они и макса в прошлое, чтобы они и
# в новом выпуске « 3 », чтобы не видели я, который я, поехали!
# в этом выпуске « спортивный интерес ». по вопросам рекламы пишите на email
# в этом выпуске ведущая алиса и дизайнер наталья обустраивают интерьер, как сделать к рабиа халилли. в этом выпуске аня хилькевич расскажет, как правильно, как правильно сделать, чтобы их к звёздам? как сделать ваш день? как сделать ваш день в 25, чтобы поднять в 25 тысяч рублей.
# с вами макс климток и это шоу правильная цена! шоу, в котором участники зарабатывают баллы, угадывая правильные цены товаров и услуг. сегодня мы узнаем, как в ценах ориентируются, как правильно, алексей кузнецов и услуг.   сегодня мы узнаем, как в ценах ориентируются, как правильно, а также можете заплатить свою цену - поставить лайк, подписаться на канал и оставить комментарий.
# добро пожаловать на аукцион шоу в котором подписчики делают ставки за вещи своего любимого блогера! сделать ставку может каждый сидящий в зале, в качестве ставки принимается всё кроме денег, ну а ставки помогает сделать ведущий шоу игорь чехов.   в этом выпуске, фанаты прохора боролись за личные вещи кумира, а также на что они готовы ради вещей.   а если уже посмотрели, то поделитесь выпуском с друзьями кто знает, может быть именно ваш кумир окажется на аукционе в следующем выпуске.
# в этом выпуске шеф, павел коклюшкин приготовит и павел коклюшкин, как правильно, как правильно, а также не менее - /   в этом выпуске вы найдете в этом выпуске вы найдете в новом выпуске “ ” - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   ссылка на пост в этом выпуске:   - /   илья - /   ссылка на пост в этом выпуске:   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья - /   илья -
# сундук открыл в этой серии!
# в новом выпуске шоу « стендап гороскоп » расскажет гороскоп расскажет про расскажет, как непросто, что ждет представителей знака и что ждет представителей знака в 2022 году.
# в этой серии сотрудник социальной службы службы с бюджетом, как всегда за ними. лиза и ольга пдн, что он тратит в этой серии!
# в этом выпуске вы узнаете, как предприниматель гостя, в мафию и пьют горячительные напитки.
# в этом выпуске легенда спорта спорта расскажет, как правильно нужно, как правильно нужно в спортзал, как выбирать в домашних условиях.
# в этой серии сотрудник социальной службы службы службы, как всегда полупановых, чтобы в этой серии.
# в этом выпуске шеф, павел коклюшкин приготовит приготовит и павел коклюшкин приготовит.
# в этом выпуске блогеры райзен football и клён вместе с ребятами, которые пройдут и решат, которые пройдут в команду, а также на футбольном поле и решат, которые пройдут в команду и решат, кто из них них.
# в этом выпуске « наше дело ».
# в этом выпуске ведущая алиса и дизайнер наташа наташа, как сделать сделать ваш день в 25, чтобы сделать ваш день чуточку радостнее и светлее.
# две красотки за тридцать тысяч рублей пытаются сделать скворечник.
# в этом выпуске - прохор останется один с учительницей, которая проверит гостя, а также на реакцию к шуткам, а также на реакцию к шуткам, которые написаны в тексте диктанта.
# предлагаю подписчикам приготовить приготовить на сковороде.
# мультнайтшоу – еженедельное юмористическое нарисованное вечернее шоу, где обсуждаются актуальные новости страны и мира. в этом выпуске мы пригласим в студию студию нагиева, увидим трейлер клип про елки, а также послушаем, увидим трейлер. по вопросам рекламы пишите на email
# в этом выпуске ассоль рабиа халилли обратилась, как правильно рабиа халилли. ей уже завтра, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что такое, что
# добро пожаловать на аукцион шоу « о чем молчат мужчины ». здесь парни говорят о том, о чем им не принято говорить. в этом выпуске вместе с оскаром.
# это спортивно - развлекательное шоу про бои в телефонной будке впервые в россии! противостояние популярного в телефонной будке! противостояние популярного в телефонной будке! противостояние популярного в телефонной будке!
# добро пожаловать на канал « бюро добрых дел »! его глава – это я, лариса брохман. а миссия нашего бюро – искать самые добрые и хорошие новости по всему миру, чтобы рассказать их вам. в этом выпуске:   -   - ксения егорова в рамках рубрики « добрый репортаж », чтобы поднять вам настроение, чтобы поднять вам настроение.   эти и другие добрые новости мы собираем регулярно, чтобы поднять вам настроение сделать ваш день чуточку радостнее и светлее.   пишите свои добрые истории нам на почту:   email   по вопросам рекламы пишите на email
# в новом выпуске шоу « спортивный интерес », чтобы не менее и его в россии!
# в новом выпуске шоу « спортивный интерес », чтобы не менее и его в комментариях под постом в instagram.   в этом выпуске вы узнаете, как предприниматель филипп, как правильно, чтобы поднять вам.   в этом выпуске вы узнаете, как предприниматель в ценах ориентируются, как правильно нужно, которая проверит.   а также на канал « наше дело ».
# сундук устроился в этой серии!
# в этом выпуске: - сазонов совместно со звездными гостями любыми способами пытаются найти и дозвониться известным артистам. сегодня в гостях –, а звонить мы будем, а также и кто же, а также кто из самых и давай.
# в этом выпуске семейная пара фермеров на farming simulator, как вести себя на улицы? как всегда? как всегда на эти? как всегда на эти вопросы. что делать на эти вопросы вы найдете в новом выпуске шоу « гейм разбор ».
# в этом выпуске вы узнаете, как предприниматель, который не менее и егор в этом выпуске!
# на фестивале на льду скорости « байкальская миля ». по вопросам рекламы пишите на льду, чтобы рекорды на льду озера байкал.
# максим константинович и ольга пдн отправляются на улицы, который не только, который и андрюха, который не только. что они и ольга пдн, что они готовы, что они готовы ради, но и кто из них них. кто из них них, кто из них них. кто из них них, кто из них них. кто из них них, кто из них них. кто из них них. поддержите видео лайком, а канал подпиской!
# в новом выпуске шоу « спортивный интерес ». по вопросам рекламы пишите на email
# в новом выпуске шоу « стендап гороскоп » расскажет про расскажет, как непросто быть, что ждет представителей знака в 2022 году.
# в этом выпуске вы узнаете, как предприниматель в новом выпуске, как правильно, как правильно, как правильно стать, что такое. что такое, как всегда в новом выпуске.
# саша белькович покажет, как правильно приготовить всемирно любимый, как правильно приготовить в домашних соусе.
# предлагаю подписчикам приготовить приготовить салат с курицей.
# carjitsu — бои в формате pop mma, где в вместо ринга бойцы сражаются в салоне. в этом выпуске, кто из них, кто из них сильнее! кто оказался сильнее и кто оказался в клетке, а кто же не только и кто оказался сильнее в клетке. кто из них сильнее сильнее!
# в этом выпуске, как всегда, как всегда, который я, который заберёт 1000$! готовьте чайоку, устраивайтесь поудобнее, поехали!
# макс случайно порвал лизе, где обсуждаются актуальные новости страны и мира. артур не умеет отправляет лизу и макса в прошлое, чтобы они узнали, чтобы они узнали, что они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, чтобы они узнали, что они они и макса в прошлое, чтобы они узнали, чтобы они узнали, что они они и макса в
# мультнайтшоу – еженедельное юмористическое нарисованное вечернее шоу, где обсуждаются актуальные новости страны и мира. в этом выпуске мы пригласим в студию студию нагиева, увидим трейлер, увидим трейлер клип на саммите.
# в этом выпуске шоу « такой расклад » вы увидите таролога ксению протаро и ведущую янину студилину. встречаемся в 20:00! тема недели и этого выпуска – карьера в семье. в прямом эфире дарья с помощью метафорических карт поможет в семье и включайте эфир!
# в этом выпуске вы узнаете, как предприниматель филипп, как правильно, которые и олю, которые в этом выпуске вы узнаете в этом выпуске, а также вы узнаете, как правильно, как правильно нужно, которые в этой серии!
# в этом выпуске вы узнаете, как предприниматель - то, как всегда, чтобы стать, обожайте!
# в этом выпуске шоу “ анкета ”, три комика - егор свирский, максим береснев и егор свирский, как зовут гостя, в этом выпуске, а также на свою интуицию, а также и какой же, а также на розливе, а также и какой самый экстремальный поступок, а также на наши каналы: антон протеинов - /
# в этом выпуске вы узнаете, как предприниматель филипп, как правильно нужно, как правильно нужно? как сделать - /   в этом выпуске, как правильно нужно? как правильно нужно? как всегда? как всегда? смотри в этом выпуске, что они готовы ради? смотри и делись своим впечатлением в комментариях под видео!
# в этом выпуске шоу « такой расклад ».
# если выпуска, как правильно, как правильно жизнь, как правильно жизнь? почему на кастинге? как правильно? как правильно? как правильно? как правильно? как правильно? ответы на эти вопросы вы найдете в новом выпуске шоу « гейм разбор ».
# в этом выпуске « 3 лошадиные », чтобы не только на что и что делать, что он и их в течение.
# в этом выпуске профессиональный - зоя, как правильно и рамис ахметов в россии.
# прогулка по городу, ведущему городу, ведущему с нами. предлагаем вместе с нами, погрузимся в непередаваемую атмосферу одного из красивейших городов россии. предлагаем вместе с нами, погрузимся в непередаваемую атмосферу одного из красивейших городов россии.
# отправились в поисках трофейной щуки. максим константинович приготовил на рыбалку. приготовили приготовил кролика в казане. приготовили видео!
# в этом выпуске “ стендап ” расскажет, как правильно, что ждет, что ждет, что ждет в 2022 году.
# сундук, тяпа и чернобыль, который не только, который не представляю, который и кто из них, который кто из них, который кто из них них, который кто из них них!
# в этом выпуске шоу « такой расклад » вы увидите таролога ксению протаро и ведущую янину студилину. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью метафорических карт поможет в семье. встречаемся в 20:00! тема недели и этого выпуска – карьера, в прямом эфире вероника с помощью
# блогерское агентство insight - шоу, где в вместо ринга бойцы в вместо ринга бойцы сражаются в клетке. в этом выпуске, а также, кто из них, кто покинет, кто покинет в клетке, а также на instagram.   в этом выпуске вы узнаете, как в клетке, а также на что они бой.   в этом выпуске вы узнаете в клетке, а также, кто же бой. кто из них сильнее бой. кто из них сильнее бой в клетке.   в этом выпуске, кто из них бой, кто покинет бой в клетке.   а также бой в клетке, а также на канал « наше дело ». youtube канал наше дело -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram артура   -   instagram -   instagram артура   -   instagram -   instagram -   instagram артура   -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -   instagram -
# группа с вами в новом выпуске артмеханика, а также часть программы часть программы в новом выпуске артмеханика, как можно расскажет, как правильно, как правильно нужно. в этом выпуске, а также на что к звёздам и как? как правильно? об этом расскажет, как в новом выпуске артмеханика, а также на что они и как правильно? об этом расскажет, как в новом выпуске артмеханика, а также на что они и как правильно? об этом расскажет, как в новом выпуске артмеханика, а также на что к звёздам.
# почти половина на связующих - это шоу, в котором кирилл фокин - сазонов совместно со звездными гостями любыми способами пытаются найти и дозвониться известным артистам шоу, а также и кто из самых ярких в клетке и кто из самых ярких? кто окажется самым лживым в компании? а кто окажется самым лживым в новом выпуске шоу « наше дело ».
# действительно ли овны самые конфликтные? а близнецы двуличные? сегодня это выяснят комики, а близнецы двуличные? сегодня это выяснят комики, а также и астролог анастасия леви?
# в этом выпуске профессиональный football ” вместе с медийными экспертами определят 22, а кто из них!
# в этом выпуске легенда спорта расскажет, как правильно нужно, как правильно нужно в спортзал, как выбирать в спортзал и как выбирать.
# в этом выпуске блогеры райзен и клён покажут в fifa 22, а также и кто из них за деньги и решат в команду.
# сегодня султан султан и авет, не только не только не только.   сегодня мы узнаем, как зовут, не просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но и просто, а также не просто, но
# в этом выпуске легенда спорта расскажет, как с бюджетом, как правильно и ольга пдн.   в этом выпуске вы узнаете, как предприниматель филипп, чтобы поднять вам на что и их, чтобы в этом выпуске, а также не только на что он, но и ольга пдн, что ждет, что ждет, что ждет, а кто из них них. кто из них них!

# %%
sample_submission.head()
# Out:
#   video_name                              generated_description
# 0      0.mp4  добро пожаловать на канал « бюро добрых дел »!...
# 1      1.mp4  знаете, как в котором комики играют и не менее...
# 2      2.mp4  вы смотрите шоу с детектором лжи « тру детекто...
# 3      3.mp4  в этом выпуске: антон протеинов - /   - /   в ...
# 4      4.mp4  в этом выпуске ведущая алиса и дизайнер наталь...
